# %% [raw]
# # 1.Consider the above text as a string, figure out the average length of the string
# l=" I am very keen in building up my career in Data Science, but not sure from where to start. If I search the web it throws me thousands of articles, few are relevant others make me confused, again I come around to the same page. Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind"

# %%
print(l)
# Out:
#  I am very keen in building up my career in Data Science  but not sure from where to start  If I search the web it throws me thousands of articles  few are relevant others make me confused  again I come around to the same page  Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind

# %%
print(len(l))
# Out:
# 328

# %% [markdown]
# #2.Lower the text in the string.

# %%
l.lower()
# Out:
# ' i am very keen in building up my career in data science, but not sure from where to start. if i search the web it throws me thousands of articles, few are relevant others make me confused, again i come around to the same page. supervised has provided me a good platform to remove all such qualms which were wrangling in my mind'

# %% [markdown]
# #3. Try to get the clean text removing the punctuation from the string.

# %%
l=l.replace(',',' ')
l=l.replace('.',' ')
print(l)
# Out:
#  I am very keen in building up my career in Data Science  but not sure from where to start  If I search the web it throws me thousands of articles  few are relevant others make me confused  again I come around to the same page  Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind

# %% [markdown]
# #4.Extract word "Data Science" from the string.

# %%
l.index('Data Science')
# Out:
# 44

# %% [markdown]
# #5.Find the frequency of words used in the string.

# %%
dict={}

# %%
li=l.split()
print(li)
# Out:
# ['I', 'am', 'very', 'keen', 'in', 'building', 'up', 'my', 'career', 'in', 'Data', 'Science', 'but', 'not', 'sure', 'from', 'where', 'to', 'start', 'If', 'I', 'search', 'the', 'web', 'it', 'throws', 'me', 'thousands', 'of', 'articles', 'few', 'are', 'relevant', 'others', 'make', 'me', 'confused', 'again', 'I', 'come', 'around', 'to', 'the', 'same', 'page', 'Supervised', 'has', 'provided', 'me', 'a', 'good', 'platform', 'to', 'remove', 'all', 'such', 'qualms', 'which', 'were', 'wrangling', 'in', 'my', 'mind']

# %%
for elements in li:
    if elements in dict:
        dict[elements]+=1
    else:
        dict.update({elements: 1})

# %%
for keys in dict:
    print(keys,"--",dict[keys])
# Out:
# I -- 3
# am -- 1
# very -- 1
# keen -- 1
# in -- 3
# building -- 1
# up -- 1
# my -- 2
# career -- 1
# Data -- 1
# Science -- 1
# but -- 1
# not -- 1
# sure -- 1
# from -- 1
# where -- 1
# to -- 3
# start -- 1
# If -- 1
# search -- 1
# the -- 2
# web -- 1
# it -- 1
# throws -- 1
# me -- 3
# thousands -- 1
# of -- 1
# articles -- 1
# few -- 1
# are -- 1
# relevant -- 1
# others -- 1
# make -- 1
# confused -- 1
# again -- 1
# come -- 1
# around -- 1
# same -- 1
# page -- 1
# Supervised -- 1
# has -- 1
# provided -- 1
# a -- 1
# good -- 1
# platform -- 1
# remove -- 1
# all -- 1
# such -- 1
# qualms -- 1
# which -- 1
# were -- 1
# wrangling -- 1
# mind -- 1

# %% [markdown]
# #6.Find all the words which occurred more than once in the string.

# %%
for words in dict:
    if dict[words]>1 :
        print(words)
# Out:
# I
# in
# my
# to
# the
# me

# %% [markdown]
# #7.Can you change the word "Supervised" to "Unsupervised" in the string

# %%
s=l.replace('Supervised','Unsupervised')
print(s)
# Out:
#  I am very keen in building up my career in Data Science  but not sure from where to start  If I search the web it throws me thousands of articles  few are relevant others make me confused  again I come around to the same page  Unsupervised has provided me a good platform to remove all such qualms which were wrangling in my mind

# %% [markdown]
# #8.Splitting of the string with a dot operator(.)

# %%
p=" I am very keen in building up my career in Data Science, but not sure from where to start. If I search the web it throws me thousands of articles, few are relevant others make me confused, again I come around to the same page. Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind"

# %%
print(p)
# Out:
#  I am very keen in building up my career in Data Science, but not sure from where to start. If I search the web it throws me thousands of articles, few are relevant others make me confused, again I come around to the same page. Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind

# %%
split_string=p.split('.')
print(split_string)
# Out:
# [' I am very keen in building up my career in Data Science, but not sure from where to start', ' If I search the web it throws me thousands of articles, few are relevant others make me confused, again I come around to the same page', ' Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind']

# %% [markdown]
# #9.Find the words from the string which ends with "e"

# %%
str=" I am very keen in building up my career in Data Science, but not sure from where to start. If I search the web it throws me thousands of articles, few are relevant others make me confused, again I come around to the same page. Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind"

# %%
str1=str.split(' ')
print(str1)
# Out:
# ['', 'I', 'am', 'very', 'keen', 'in', 'building', 'up', 'my', 'career', 'in', 'Data', 'Science,', 'but', 'not', 'sure', 'from', 'where', 'to', 'start.', 'If', 'I', 'search', 'the', 'web', 'it', 'throws', 'me', 'thousands', 'of', 'articles,', 'few', 'are', 'relevant', 'others', 'make', 'me', 'confused,', 'again', 'I', 'come', 'around', 'to', 'the', 'same', 'page.', 'Supervised', 'has', 'provided', 'me', 'a', 'good', 'platform', 'to', 'remove', 'all', 'such', 'qualms', 'which', 'were', 'wrangling', 'in', 'my', 'mind']

# %%
for i in range(len(str1)):
  #  print(str1[i])
    if str1[i].endswith('e') :
        print(str1[i])
# Out:
# sure
# where
# the
# me
# are
# make
# me
# come
# the
# same
# me
# remove
# were

# %% [markdown]
# #10.Figure out number of a's used in the string.

# %%
str
# Out:
# ' I am very keen in building up my career in Data Science, but not sure from where to start. If I search the web it throws me thousands of articles, few are relevant others make me confused, again I come around to the same page. Supervised has provided me a good platform to remove all such qualms which were wrangling in my mind'

# %%
count=0
for i in range(len(str)):
    if str[i]=='a' :
        count+=1
print("a is repeated %d times in the string"% count)
# Out:
# a is repeated 22 times in the string
