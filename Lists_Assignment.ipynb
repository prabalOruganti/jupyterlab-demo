# %%
AI_Companies=['Amazon','Facebook','HiSilicon','Google','Apple','Microsoft','SenseTime']

# %% [raw]
# #1. Sort the list in ascending order

# %%
AI_Companies.sort()

# %%
AI_Companies
# Out:
# ['Amazon',
#  'Apple',
#  'Facebook',
#  'Google',
#  'HiSilicon',
#  'Microsoft',
#  'SenseTime']

# %% [markdown]
# #2.Add multiple companies at once 'Nvidia', 'OpenAI' , 'Qualcomm' and 'Reliance' to the lis

# %%
AI_Companies=['Amazon','Facebook','HiSilicon','Google','Apple','Microsoft','SenseTime']

# %%
AI_Companies.extend(['Nvidia','OpenAI','Qualcomm','Reliance'])
AI_Companies
# Out:
# ['Amazon',
#  'Facebook',
#  'HiSilicon',
#  'Google',
#  'Apple',
#  'Microsoft',
#  'SenseTime',
#  'Nvidia',
#  'OpenAI',
#  'Qualcomm',
#  'Reliance']

# %% [raw]
# #3.Make every alphabet, string inside the list into lower case letters.

# %%
len(AI_Companies)
# Out:
# 11

# %%
lst=[x.lower() for x in AI_Companies]

# %%
print(lst)
# Out:
# ['amazon', 'facebook', 'hisilicon', 'google', 'apple', 'microsoft', 'sensetime', 'nvidia', 'openai', 'qualcomm', 'reliance']

# %% [raw]
# #4.Eliminate 'Reliance' from the list

# %%
lst.pop()
# Out:
# 'reliance'

# %% [raw]
# #5. Extract 'Facebook', 'Google' and 'Microsoft' using a single command

# %%
lst[1:6:2]
# Out:
# ['facebook', 'google', 'microsoft']
